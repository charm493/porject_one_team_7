# %%
import pandas as pd
from atwater_functions import load_data, merge_data, plot_with_dividers
import matplotlib.pyplot as plt
import hvplot

# %%
stock_file_path = 'raw_data/Energy Select Sector SPDR Fund.csv'
political_file_path = 'raw_data/political_control_final.csv'

# %%
# Load data
stock_data, political_data = load_data(stock_file_path, political_file_path)

# Merge datasets
merged_data = merge_data(stock_data, political_data)

# %%
#with pd.option_context('display.max_rows', None):
#    display(merged_data)
merged_data['Sector'] = "Energy"
merged_data
# Out:
#            Date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0    2024-12-06    95.50   95.660  90.845     91.02            91.0200
# 1    2024-11-29    97.25   97.740  94.780     95.53            95.5300
# 2    2024-11-22    95.48   97.920  94.925     97.27            97.2700
# 3    2024-11-15    93.77   95.690  92.930     94.73            94.7300
# 4    2024-11-08    88.63   94.265  88.510     93.75            93.7500
# ...         ...      ...      ...     ...       ...                ...
# 2268 1999-12-10    27.19   27.310  26.160     26.31            13.7751
# 2269 1999-12-03    27.11   27.520  26.920     27.13            14.2045
# 2270 1999-11-26    28.48   28.560  27.220     27.25            14.2673
# 2271 1999-11-19    27.98   29.190  27.880     28.34            14.8380
# 2272 1999-11-12    25.78   28.000  25.780     27.88            14.5972
#
#       6. volume  7. dividend amount Start Date   End Date   President  \
# ...

# %%
energy_plot = plot_with_dividers(merged_data,political_file_path)

# %%
stock_file_path = 'raw_data/Health Care Select Sector SPDR Fund.csv'
political_file_path = 'raw_data/political_control_final.csv'

# Load data
stock_data, political_data = load_data(stock_file_path, political_file_path)

# Merge datasets
hc_merged_data = merge_data(stock_data, political_data)

# %%
hc_merged_data['Sector'] = "Health Care"
hc_merged_data
combined_sectors = pd.concat([merged_data, hc_merged_data], ignore_index=True)
combined_sectors
# Out:
#            Date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0    2024-12-06    95.50   95.660  90.845     91.02            91.0200
# 1    2024-11-29    97.25   97.740  94.780     95.53            95.5300
# 2    2024-11-22    95.48   97.920  94.925     97.27            97.2700
# 3    2024-11-15    93.77   95.690  92.930     94.73            94.7300
# 4    2024-11-08    88.63   94.265  88.510     93.75            93.7500
# ...         ...      ...      ...     ...       ...                ...
# 4541 1999-12-10    29.36   30.250  29.250     29.89            20.5344
# 4542 1999-12-03    28.52   29.660  28.380     29.25            20.0947
# 4543 1999-11-26    29.00   29.090  28.440     28.69            19.7100
# 4544 1999-11-19    29.00   29.660  29.000     29.31            20.1359
# 4545 1999-11-12    28.00   29.130  27.670     29.06            19.9642
#
#       6. volume  7. dividend amount Start Date   End Date   President  \
# ...

# %%
stock_file_path = 'raw_data/Consumer Staples Select Sector SPDR Fund.csv'
political_file_path = 'raw_data/political_control_final.csv'

# Load data
stock_data, political_data = load_data(stock_file_path, political_file_path)

# Merge datasets
cs_merged_data = merge_data(stock_data, political_data)

cs_merged_data['Sector'] = "Consumer Staples"
cs_merged_data
combined_sectors = pd.concat([combined_sectors, cs_merged_data], ignore_index=True)
combined_sectors
# Out:
#            Date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0    2024-12-06    95.50   95.660  90.845     91.02            91.0200
# 1    2024-11-29    97.25   97.740  94.780     95.53            95.5300
# 2    2024-11-22    95.48   97.920  94.925     97.27            97.2700
# 3    2024-11-15    93.77   95.690  92.930     94.73            94.7300
# 4    2024-11-08    88.63   94.265  88.510     93.75            93.7500
# ...         ...      ...      ...     ...       ...                ...
# 6814 1999-12-10    24.88   24.920  23.280     23.72            13.1754
# 6815 1999-12-03    25.06   25.360  24.590     25.11            13.9475
# 6816 1999-11-26    24.95   25.640  24.940     25.25            14.0253
# 6817 1999-11-19    24.70   25.270  24.590     25.00            13.8864
# 6818 1999-11-12    24.91   25.170  24.420     24.81            13.7809
#
#       6. volume  7. dividend amount Start Date   End Date   President  \
# ...

# %%
stock_file_path = 'raw_data/Financial Select Sector SPDR Fund.csv'
political_file_path = 'raw_data/political_control_final.csv'

# Load data
stock_data, political_data = load_data(stock_file_path, political_file_path)

# Merge datasets
financial_merged_data = merge_data(stock_data, political_data)

financial_merged_data['Sector'] = "Financial"

combined_sectors = pd.concat([combined_sectors, financial_merged_data], ignore_index=True)
combined_sectors
# Out:
#            Date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0    2024-12-06    95.50   95.660  90.845     91.02            91.0200
# 1    2024-11-29    97.25   97.740  94.780     95.53            95.5300
# 2    2024-11-22    95.48   97.920  94.925     97.27            97.2700
# 3    2024-11-15    93.77   95.690  92.930     94.73            94.7300
# 4    2024-11-08    88.63   94.265  88.510     93.75            93.7500
# ...         ...      ...      ...     ...       ...                ...
# 9087 1999-12-10    24.81   24.810  23.610     24.41            12.0398
# 9088 1999-12-03    24.28   25.410  24.030     24.94            12.3012
# 9089 1999-11-26    25.50   25.500  24.630     24.63            12.1483
# 9090 1999-11-19    25.88   26.780  25.560     25.59            12.6218
# 9091 1999-11-12    25.97   26.000  24.640     25.94            12.7944
#
#       6. volume  7. dividend amount Start Date   End Date   President  \
# ...

# %%
stock_file_path = 'raw_data/Technology Select Sector SPDR Fund.csv'
political_file_path = 'raw_data/political_control_final.csv'

# Load data
stock_data, political_data = load_data(stock_file_path, political_file_path)

# Merge datasets
tech_merged_data = merge_data(stock_data, political_data)

tech_merged_data['Sector'] = "Technology"

combined_sectors = pd.concat([combined_sectors, tech_merged_data], ignore_index=True)
combined_sectors
# Out:
#             Date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0     2024-12-06    95.50   95.660  90.845     91.02            91.0200
# 1     2024-11-29    97.25   97.740  94.780     95.53            95.5300
# 2     2024-11-22    95.48   97.920  94.925     97.27            97.2700
# 3     2024-11-15    93.77   95.690  92.930     94.73            94.7300
# 4     2024-11-08    88.63   94.265  88.510     93.75            93.7500
# ...          ...      ...      ...     ...       ...                ...
# 11360 1999-12-10    49.47   50.340  48.590     49.69            37.1538
# 11361 1999-12-03    48.38   50.130  46.470     49.63            37.1089
# 11362 1999-11-26    47.44   49.000  46.780     48.53            36.2864
# 11363 1999-11-19    45.34   47.630  44.860     47.55            35.5537
# 11364 1999-11-12    43.19   45.630  43.190     45.25            33.8339
#
#        6. volume  7. dividend amount Start Date   End Date   President  \
# ...

# %%
stock_file_path = 'raw_data/Utilities Select Sector SPDR Fund.csv'
political_file_path = 'raw_data/political_control_final.csv'

# Load data
stock_data, political_data = load_data(stock_file_path, political_file_path)

# Merge datasets
utility_merged_data = merge_data(stock_data, political_data)

utility_merged_data['Sector'] = "Utilities"

combined_sectors = pd.concat([combined_sectors, utility_merged_data], ignore_index=True)
combined_sectors
# Out:
#             Date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0     2024-12-06    95.50   95.660  90.845     91.02            91.0200
# 1     2024-11-29    97.25   97.740  94.780     95.53            95.5300
# 2     2024-11-22    95.48   97.920  94.925     97.27            97.2700
# 3     2024-11-15    93.77   95.690  92.930     94.73            94.7300
# 4     2024-11-08    88.63   94.265  88.510     93.75            93.7500
# ...          ...      ...      ...     ...       ...                ...
# 13633 1999-12-10    29.64   29.690  29.080     29.08            11.9443
# 13634 1999-12-03    28.66   29.840  28.500     29.48            12.1086
# 13635 1999-11-26    29.20   29.280  28.550     28.92            11.8786
# 13636 1999-11-19    29.45   29.800  29.130     29.38            12.0675
# 13637 1999-11-12    29.69   29.880  29.340     29.56            12.1415
#
#        6. volume  7. dividend amount Start Date   End Date   President  \
# ...

# %%
combined_sectors = combined_sectors.set_index("Date")
combined_sectors
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# Date
# 2024-12-06    95.50   95.660  90.845     91.02            91.0200   60731796
# 2024-11-29    97.25   97.740  94.780     95.53            95.5300   43557441
# 2024-11-22    95.48   97.920  94.925     97.27            97.2700   61023116
# 2024-11-15    93.77   95.690  92.930     94.73            94.7300   54588819
# 2024-11-08    88.63   94.265  88.510     93.75            93.7500   72608319
# ...             ...      ...     ...       ...                ...        ...
# 1999-12-10    29.64   29.690  29.080     29.08            11.9443     145700
# 1999-12-03    28.66   29.840  28.500     29.48            12.1086      82200
# 1999-11-26    29.20   29.280  28.550     28.92            11.8786      89000
# 1999-11-19    29.45   29.800  29.130     29.38            12.0675      59400
# 1999-11-12    29.69   29.880  29.340     29.56            12.1415      52100
#
# ...

# %%
combined_sectors = combined_sectors.drop(columns=['1. open', '2. high', '3. low', '5. adjusted close', '7. dividend amount'])
combined_sectors
# Out:
#             4. close  6. volume Start Date   End Date   President       House  \
# Date
# 2024-12-06     91.02   60731796 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-29     95.53   43557441 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-22     97.27   61023116 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-15     94.73   54588819 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-08     93.75   72608319 2023-01-20 2025-01-19  Democratic  Republican
# ...              ...        ...        ...        ...         ...         ...
# 1999-12-10     29.08     145700 1999-01-20 2001-01-19  Democratic  Republican
# 1999-12-03     29.48      82200 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-26     28.92      89000 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-19     29.38      59400 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-12     29.56      52100 1999-01-20 2001-01-19  Democratic  Republican
#
# ...

# %%
combined_sectors = combined_sectors.rename(columns={
    "4. close": "Close",
    "6. volume": "Volume"
})
combined_sectors
# Out:
#             Close    Volume Start Date   End Date   President       House  \
# Date
# 2024-12-06  91.02  60731796 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-29  95.53  43557441 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-22  97.27  61023116 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-15  94.73  54588819 2023-01-20 2025-01-19  Democratic  Republican
# 2024-11-08  93.75  72608319 2023-01-20 2025-01-19  Democratic  Republican
# ...           ...       ...        ...        ...         ...         ...
# 1999-12-10  29.08    145700 1999-01-20 2001-01-19  Democratic  Republican
# 1999-12-03  29.48     82200 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-26  28.92     89000 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-19  29.38     59400 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-12  29.56     52100 1999-01-20 2001-01-19  Democratic  Republican
#
#                 Senate     Sector
# Date
# ...

# %%
combined_sectors = combined_sectors.sort_values(by="Date", ascending=False)
combined_sectors
# Out:
#              Close    Volume Start Date   End Date   President       House  \
# Date
# 2024-12-06   91.02  60731796 2023-01-20 2025-01-19  Democratic  Republican
# 2024-12-06  144.28  31549199 2023-01-20 2025-01-19  Democratic  Republican
# 2024-12-06   79.69  46781304 2023-01-20 2025-01-19  Democratic  Republican
# 2024-12-06  240.84  19053741 2023-01-20 2025-01-19  Democratic  Republican
# 2024-12-06   82.38  51724124 2023-01-20 2025-01-19  Democratic  Republican
# ...            ...       ...        ...        ...         ...         ...
# 1999-11-12   27.88    775400 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-12   29.06     89400 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-12   45.25   2677300 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-12   24.81    151700 1999-01-20 2001-01-19  Democratic  Republican
# 1999-11-12   29.56     52100 1999-01-20 2001-01-19  Democratic  Republican
#
#                 Senate            Sector
# Date
# ...

# %%
# Political Scenarios
uniques_df = combined_sectors.copy().reset_index()
columns = ['President', 'House', 'Senate']
uniques_df = uniques_df[columns].drop_duplicates()
uniques_df.reset_index(drop=True)
uniques_df
# Out:
#        President       House      Senate
# 0     Democratic  Republican  Democratic
# 582   Republican  Republican  Republican
# 583   Democratic  Democratic  Democratic
# 1795  Republican  Democratic  Republican
# 4218  Democratic  Republican  Republican
# 9030  Republican  Democratic  Democratic

# %%
# lame duck scenario
# Filter for dates after November 10 and before January 20 of any year
combined_sectors = combined_sectors.reset_index()
lame_duck_df = combined_sectors[
    (combined_sectors['Date'].dt.month == 11) & (combined_sectors['Date'].dt.day > 10) |
    (combined_sectors['Date'].dt.month == 12) |
    (combined_sectors['Date'].dt.month == 1) & (combined_sectors['Date'].dt.day < 20)
]
lame_duck_df
# Out:
#             Date   Close    Volume Start Date   End Date   President  \
# 0     2024-12-06   91.02  60731796 2023-01-20 2025-01-19  Democratic
# 1     2024-12-06  144.28  31549199 2023-01-20 2025-01-19  Democratic
# 2     2024-12-06   79.69  46781304 2023-01-20 2025-01-19  Democratic
# 3     2024-12-06  240.84  19053741 2023-01-20 2025-01-19  Democratic
# 4     2024-12-06   82.38  51724124 2023-01-20 2025-01-19  Democratic
# ...          ...     ...       ...        ...        ...         ...
# 13633 1999-11-12   27.88    775400 1999-01-20 2001-01-19  Democratic
# 13634 1999-11-12   29.06     89400 1999-01-20 2001-01-19  Democratic
# 13635 1999-11-12   45.25   2677300 1999-01-20 2001-01-19  Democratic
# 13636 1999-11-12   24.81    151700 1999-01-20 2001-01-19  Democratic
# 13637 1999-11-12   29.56     52100 1999-01-20 2001-01-19  Democratic
#
#             House      Senate            Sector
# 0      Republican  Democratic            Energy
# ...

# %%
# define a method to generate plot for checking avg close price base on house and Sector
# df: must have Start Date, President, House, Senate, Sector, and Close columns
# house: can only be a value form ["President", "House", "Senate"]
# sector: can be any value in sector column

def generate_sector_Plot(df, house, sector, index):

    group = df.loc[df["Sector"] == sector].groupby([house, "Start Date"])["Close"].mean()
    group_df = pd.DataFrame(group).reset_index()
    group_df["Start Date"] = group_df["Start Date"].dt.strftime('%Y-%m-%d')
    group_df = group_df.pivot(index='Start Date', columns=house, values='Close')
    group_df.plot.bar(ax=axes[index], xlabel="Start Date", ylabel="Close Price", title=sector+" Stock", color=["royalblue", "lightcoral"])


# get all sector
def get_all_sector(df):
    return df["Sector"].unique()


departments = ["President", "House", "Senate"]

for sector in get_all_sector(lame_duck_df):
    # Create a figure and subplots
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))    
    index = 0
    for dep in departments:
        generate_sector_Plot(lame_duck_df, dep, sector, index)
        # axes[index].set_title()
        index += 1
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 24
#      20 departments = ["President", "House", "Senate"]
#      22 for sector in get_all_sector(lame_duck_df):
#      23     # Create a figure and subplots
# ---> 24     fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4), title="lll")
#      25     index = 0
#      26     for dep in departments:
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/pyplot.py:1759, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1604 def subplots(
#    1605     nrows: int = 1, ncols: int = 1, *,
#    1606     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)
#    1613     **fig_kw
#    1614 ) -> tuple[Figure, Any]:
#    1615     """
#    1616     Create a figure and a set of subplots.
#    1617
#    (...)
# ...

# %%
# Plot the data as an area chart 
plt.figure(figsize=(12, 6)) 
plt.fill_between(lame_duck_df['Date'], lame_duck_df['Close'], color=("skyblue"), alpha=0.4) 
plt.plot(lame_duck_df['Date'], lame_duck_df['Close'], color="Slateblue", alpha=0.6, linewidth=2) 
plt.xlabel('Date') 
plt.ylabel('Close') 
plt.title('Change Over Time') 
plt.grid(True) 
plt.show()

# %%
group_df = lame_duck_df.groupby("Sector")["Close"].mean()
group_df.plot.bar()
# Out:
# <Axes: xlabel='Sector'>

# %%
group_df = lame_duck_df.loc[lame_duck_df["Sector"] == "Energy"]["Close"].pct_change()
group_df.plot()
# Out:
# <Axes: >

# %%
grouping_close = lame_duck_df[lame_duck_df["Sector"] == "Energy"].groupby(by=["Start Date", "End Date", "President"]).mean("Close")
grouping_close = grouping_close.reset_index()
plt.plot(grouping_close['Start Date'], grouping_close['Close'])

for i, j in grouping_close.iterrows():
    plt.axvline(x=pd.Timestamp(j["Start Date"]), color=("blue" if j["President"] == "Democratic" else "red"), linestyle='--', label='Event Date')
plt.show()

# %%
grouping = lame_duck_df[lame_duck_df["Sector"] == "Energy"].groupby(by=["Start Date", "End Date", "President"]).mean("Volume")
grouping = grouping.reset_index()
grouping
plt.plot(grouping['Start Date'], grouping['Volume'])
for i, j in grouping.iterrows():
    plt.axvline(x=pd.Timestamp(j["Start Date"]), color=("blue" if j["President"] == "Democratic" else "red"), linestyle='--', label='Event Date')
plt.show()

# %%
# industry performance at beginning of a period vs end of a period between elections, compare according to who controls 2/3

# %%
# Forecast upcoming 2 years of stock performance by sector
